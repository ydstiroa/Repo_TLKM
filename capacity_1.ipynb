# %%
from google.colab import drive
drive._mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = r'drive/My Drive/Colab Notebooks/data_2.xlsx'
dataset
# Out:
# 'drive/My Drive/Colab Notebooks/data_2.xlsx'

# %%
import pandas as pd

df = pd.read_excel(dataset)
df.head()
# Out:
#    Unnamed: 0       Date  ...  MaxUtil_Link_2  Capacity_2
# 0         NaN 2020-01-01  ...          128.21         200
# 1         NaN 2020-02-01  ...          129.80         200
# 2         NaN 2020-03-01  ...          124.44         200
# 3         NaN 2020-04-01  ...          127.55         200
# 4         NaN 2020-05-01  ...          130.25         200
#
# [5 rows x 6 columns]

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df1 = df[['MaxUtil_Link_1']]
df2 = df[['Capacity_1']]

# %%
df1 = df['MaxUtil_Link_1'][20:].values
df2 = df['Capacity_1'][19:].values

# %%
flag = df2[0]
cap = 1
x= []

for i in df1:
  # print(i)
  z = 75/100*flag
  # print(z)
  if i > z:
    # print(i)
    # print('----')
    # print(z)
    count = flag+100
    x.append(count)
  elif i == z :
    count += 100
    x.append(count)
  else:
    count = flag
    x.append(count)

x
# Out:
# [600, 600, 700, 700, 700, 700, 700, 700]

# %%
df =  df.drop(columns=['Capacity_2','MaxUtil_Link_2','Date'])
